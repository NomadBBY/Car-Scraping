# %%
from bs4 import BeautifulSoup
import requests

# %%
def fetch_soup(website_url: str):
    response = requests.get(website_url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, "html.parser")
        return soup
    else:
        print(f"Unable to fetch page: {website_url}")
        return None

# %%
def fetch_div(soup, div_name: str, class_name: str):
    if soup:
        div = soup.find(div_name, class_=class_name)
        return div
    return None

# %%
def fetch_subtitles(div, subtitle_name: str, subtitle_class_name:str):
    if div:
        #subtitles = div.find_all('p', class_='cars__subtitle')
        subtitles = div.find_all(subtitle_name, class_=subtitle_class_name)
        return subtitles
    return []

# %%
link = "https://lv.brcauto.eu/lietoti-auto?city=5&search=1&makes=31473"

# %%
soup = fetch_soup(link)
if soup:
    print("Connection Made", '\n')
    print(f"Title of the page: {soup.title.string}", '\n')

    div = fetch_div(soup, 'div' , "cars-container row-3")
    if div:
        print("Found the div with class 'cars-container row-3'")
        print(div.prettify())
    else:
        print("Div with class 'cars-container row-3' not found")
        
else:
    print("Failed to fetch the page")
# Out:
# Connection Made
#
# Title of the page: Lietoti auto plašā klāstā | BRC Autocentrs
#
# Found the div with class 'cars-container row-3'
# <div class="cars-container row-3">
#  <div class="cars-wrapper">
#   <div class="cars">
#    <div class="cars__top">
#     <h2 class="cars__title">
#      <a href="https://lv.brcauto.eu/automobilis/c863896-porsche-911-4.0l-automatiska">
#       Porsche 911 GT3 Clubsport
#      </a>
#     </h2>
#     <p class="cars__subtitle">
#      2018 | 4.0 Benzīns | Automātiskā | 19627 km | 368 kW (500 HP) | Melna
#     </p>
#    </div>
#    <div class="cars__img">
#     <a href="https://lv.brcauto.eu/automobilis/c863896-porsche-911-4.0l-automatiska">
#      <img alt="Porsche 911 GT3 Clubsport" class="lazy cars__img-primary" data-src="https://media.brcauto.eu/cars/list_grid/863896_1.jpg" src="#">
#      </img>
#     </a>
#    </div>
#    <div class="cars__middle">
#     <div class="flex flex-wrap justify-end lg:justify-between items-center">
#      <div class="w-full lg:w-auto cars-price text-right pt-1">
#       €149900
#      </div>
#      <div class="inline-flex items-center">
#       <span class="cars-bolder-txt pt-1">
#        € 2318
#       </span>
#       <div class="price-block-green ml-2">
#        <span>
#         €
#        </span>
#        <span class="text-xs">
#         mēn.
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="cars__bottom">
#     <div class="border-b">
#      <div class="inline-flex items-end">
#       <a class="button-more" href="https://lv.brcauto.eu/automobilis/c863896-porsche-911-4.0l-automatiska">
#        <svg class="fill-current" height="12" width="7">
#         <use xlink:href="#arrow-r">
#         </use>
#        </svg>
#       </a>
#       <span class="pl-4 mb-2">
#       </span>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
#  <div class="cars-wrapper">
#   <div class="cars">
#    <div class="cars__top">
#     <h2 class="cars__title">
#      <a href="https://lv.brcauto.eu/automobilis/c859670-porsche-taycan-l-automatiska">
#       Porsche Taycan Performance Performance Plus
#      </a>
#     </h2>
#     <p class="cars__subtitle">
#      Elektro | Automātiskā | 280 kW (381 AG) | 65588 km
#     </p>
#    </div>
#    <div class="cars__img">
#     <span class="block">
#      <img alt="EV!" class="cars__flag cars__flag_ev" height="40" src="https://lv.brcauto.eu/images/ev-icon.png" width="40">
#      </img>
#     </span>
#     <a href="https://lv.brcauto.eu/automobilis/c859670-porsche-taycan-l-automatiska">
#      <img alt="Porsche Taycan Performance Performance Plus" class="lazy cars__img-primary" data-src="https://media.brcauto.eu/cars/list_grid/859670_1.jpg" src="#">
#      </img>
#     </a>
#    </div>
#    <div class="cars__middle">
#     <div class="flex flex-wrap justify-end lg:justify-between items-center">
#      <div class="w-full lg:w-auto cars-price text-right pt-1">
#       €62000
#      </div>
#      <div class="inline-flex items-center">
#       <span class="cars-bolder-txt pt-1">
#        € 959
#       </span>
#       <div class="price-block-green ml-2">
#        <span>
#         €
#        </span>
#        <span class="text-xs">
#         mēn.
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="cars__bottom">
#     <div class="border-b">
#      <div class="inline-flex items-end">
#       <a class="button-more" href="https://lv.brcauto.eu/automobilis/c859670-porsche-taycan-l-automatiska">
#        <svg class="fill-current" height="12" width="7">
#         <use xlink:href="#arrow-r">
#         </use>
#        </svg>
#       </a>
#       <span class="pl-4">
#        <span class="block cars-status">
#         Rezervēta
#        </span>
#        <span class="block">
#         PVN iekļauts
#        </span>
#       </span>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
#  <div class="cars-wrapper">
#   <div class="cars">
#    <div class="cars__top">
#     <h2 class="cars__title">
#      <a href="https://lv.brcauto.eu/automobilis/c861006-porsche-cayenne-3.0l-automatiska">
#       Porsche Cayenne 3.0T AT
#      </a>
#     </h2>
#     <p class="cars__subtitle">
#      2018 | 3.0 Benzīns | Automātiskā | 85410 km | 250 kW (340 HP) | Melna
#     </p>
#    </div>
#    <div class="cars__img">
#     <a href="https://lv.brcauto.eu/automobilis/c861006-porsche-cayenne-3.0l-automatiska">
#      <img alt="Porsche Cayenne 3.0T AT" class="lazy cars__img-primary" data-src="https://media.brcauto.eu/cars/list_grid/861006_1.jpg" src="#">
#      </img>
#     </a>
#    </div>
#    <div class="cars__middle">
#     <div class="flex flex-wrap justify-end lg:justify-between items-center">
#      <div class="w-full lg:w-auto cars-price text-right pt-1">
#       €46500
#      </div>
#      <div class="inline-flex items-center">
#       <span class="cars-bolder-txt pt-1">
#        € 719
#       </span>
#       <div class="price-block-green ml-2">
#        <span>
#         €
#        </span>
#        <span class="text-xs">
#         mēn.
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="cars__bottom">
#     <div class="border-b">
#      <div class="inline-flex items-end">
#       <a class="button-more" href="https://lv.brcauto.eu/automobilis/c861006-porsche-cayenne-3.0l-automatiska">
#        <svg class="fill-current" height="12" width="7">
#         <use xlink:href="#arrow-r">
#         </use>
#        </svg>
#       </a>
#       <span class="pl-4 mb-2">
#       </span>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
#  <div class="cars-wrapper">
#   <div class="cars">
#    <div class="cars__top">
#     <h2 class="cars__title">
#      <a href="https://lv.brcauto.eu/automobilis/c861843-porsche-cayenne-3.6l-mehaniska">
#       Porsche Cayenne M/T
#      </a>
#     </h2>
#     <p class="cars__subtitle">
#      2007 | 3.6 Benzīns | Mehāniskā | 92070 km | 213 kW (290 HP) | Melna
#     </p>
#    </div>
#    <div class="cars__img">
#     <a href="https://lv.brcauto.eu/automobilis/c861843-porsche-cayenne-3.6l-mehaniska">
#      <img alt="Porsche Cayenne M/T" class="lazy cars__img-primary" data-src="https://media.brcauto.eu/cars/list_grid/861843_1.jpg" src="#"/>
#     </a>
#    </div>
#    <div class="cars__middle">
#     <div class="flex flex-wrap justify-end lg:justify-between items-center">
#      <div class="w-full lg:w-auto cars-price text-right pt-1">
#       €13900
#      </div>
#      <div class="inline-flex items-center">
#       <span class="cars-bolder-txt pt-1">
#        € 215
#       </span>
#       <div class="price-block-green ml-2">
#        <span>
#         €
#        </span>
#        <span class="text-xs">
#         mēn.
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="cars__bottom">
#     <div class="border-b">
#      <div class="inline-flex items-end">
#       <a class="button-more" href="https://lv.brcauto.eu/automobilis/c861843-porsche-cayenne-3.6l-mehaniska">
#        <svg class="fill-current" height="12" width="7">
#         <use xlink:href="#arrow-r">
#         </use>
#        </svg>
#       </a>
#       <span class="pl-4 mb-2">
#       </span>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
#  <div class="cars-wrapper">
#   <div class="cars">
#    <div class="cars__top">
#     <h2 class="cars__title">
#      <a href="https://lv.brcauto.eu/automobilis/c861329-porsche-997-3.8l-mehaniska">
#       Porsche 997 Targa 4S M/T
#      </a>
#     </h2>
#     <p class="cars__subtitle">
#      2006 | 3.8 Benzīns | Mehāniskā | 46714 km | 261 kW (355 HP) | Sarkana
#     </p>
#    </div>
#    <div class="cars__img">
#     <a href="https://lv.brcauto.eu/automobilis/c861329-porsche-997-3.8l-mehaniska">
#      <img alt="Porsche 997 Targa 4S M/T" class="lazy cars__img-primary" data-src="https://media.brcauto.eu/cars/list_grid/861329_1.jpg" src="#"/>
#     </a>
#    </div>
#    <div class="cars__middle">
#     <div class="flex flex-wrap justify-end lg:justify-between items-center">
#      <div class="w-full lg:w-auto cars-price text-right pt-1">
#       €57000
#      </div>
#      <div class="inline-flex items-center">
#       <span class="cars-bolder-txt pt-1">
#        € 881
#       </span>
#       <div class="price-block-green ml-2">
#        <span>
#         €
#        </span>
#        <span class="text-xs">
#         mēn.
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="cars__bottom">
#     <div class="border-b">
#      <div class="inline-flex items-end">
#       <a class="button-more" href="https://lv.brcauto.eu/automobilis/c861329-porsche-997-3.8l-mehaniska">
#        <svg class="fill-current" height="12" width="7">
#         <use xlink:href="#arrow-r">
#         </use>
#        </svg>
#       </a>
#       <span class="pl-4">
#        <span class="block cars-status">
#         SAZINĀTIES
#        </span>
#       </span>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
#  <div class="cars-wrapper">
#   <div class="cars">
#    <div class="cars__top">
#     <h2 class="cars__title">
#      <a href="https://lv.brcauto.eu/automobilis/c849747-porsche-968-3.0l-mehaniska">
#       Porsche 968 Coupe Manual M030
#      </a>
#     </h2>
#     <p class="cars__subtitle">
#      1993 | 3.0 Benzīns | Mehāniskā | 114652 mil | 176 kW (239 HP) | Balta
#     </p>
#    </div>
#    <div class="cars__img">
#     <a href="https://lv.brcauto.eu/automobilis/c849747-porsche-968-3.0l-mehaniska">
#      <img alt="Porsche 968 Coupe Manual M030" class="lazy cars__img-primary" data-src="https://media.brcauto.eu/cars/list_grid/849747_1.jpg" src="#"/>
#     </a>
#    </div>
#    <div class="cars__middle">
#     <div class="flex flex-wrap justify-end lg:justify-between items-center">
#      <div class="w-full lg:w-auto cars-price text-right pt-1">
#       €22500
#      </div>
#      <div class="inline-flex items-center">
#       <span class="cars-bolder-txt pt-1">
#        € 348
#       </span>
#       <div class="price-block-green ml-2">
#        <span>
#         €
#        </span>
#        <span class="text-xs">
#         mēn.
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="cars__bottom">
#     <div class="border-b">
#      <div class="inline-flex items-end">
#       <a class="button-more" href="https://lv.brcauto.eu/automobilis/c849747-porsche-968-3.0l-mehaniska">
#        <svg class="fill-current" height="12" width="7">
#         <use xlink:href="#arrow-r">
#         </use>
#        </svg>
#       </a>
#       <span class="pl-4 mb-2">
#       </span>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
#  <div class="cars-wrapper">
#   <div class="cars">
#    <div class="cars__top">
#     <h2 class="cars__title">
#      <a href="https://lv.brcauto.eu/automobilis/c862790-porsche-boxster-2.7l-mehaniska">
#       Porsche Boxster M/T
#      </a>
#     </h2>
#     <p class="cars__subtitle">
#      2003 | 2.7 Benzīns | Mehāniskā | 93311 km | 168 kW (228 HP) | Sudraba
#     </p>
#    </div>
#    <div class="cars__img">
#     <a href="https://lv.brcauto.eu/automobilis/c862790-porsche-boxster-2.7l-mehaniska">
#      <img alt="Porsche Boxster M/T" class="lazy cars__img-primary" data-src="https://media.brcauto.eu/cars/list_grid/862790_1.jpg" src="#"/>
#     </a>
#    </div>
#    <div class="cars__middle">
#     <div class="flex flex-wrap justify-end lg:justify-between items-center">
#      <div class="w-full lg:w-auto cars-price text-right pt-1">
#       €16900
#      </div>
#      <div class="inline-flex items-center">
#       <span class="cars-bolder-txt pt-1">
#        € 261
#       </span>
#       <div class="price-block-green ml-2">
#        <span>
#         €
#        </span>
#        <span class="text-xs">
#         mēn.
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="cars__bottom">
#     <div class="border-b">
#      <div class="inline-flex items-end">
#       <a class="button-more" href="https://lv.brcauto.eu/automobilis/c862790-porsche-boxster-2.7l-mehaniska">
#        <svg class="fill-current" height="12" width="7">
#         <use xlink:href="#arrow-r">
#         </use>
#        </svg>
#       </a>
#       <span class="pl-4 mb-2">
#       </span>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
#  <div class="cars-wrapper">
#   <div class="cars">
#    <div class="cars__top">
#     <h2 class="cars__title">
#      <a href="https://lv.brcauto.eu/automobilis/c863142-porsche-boxster-2.7l-automatiska">
#       Porsche Boxster M/T
#      </a>
#     </h2>
#     <p class="cars__subtitle">
#      2002 | 2.7 Benzīns | Automātiskā | 38294 km | 162 kW (220 HP) | Sarkana
#     </p>
#    </div>
#    <div class="cars__img">
#     <a href="https://lv.brcauto.eu/automobilis/c863142-porsche-boxster-2.7l-automatiska">
#      <img alt="Porsche Boxster M/T" class="lazy cars__img-primary" data-src="https://media.brcauto.eu/cars/list_grid/863142_1.jpg" src="#"/>
#     </a>
#    </div>
#    <div class="cars__middle">
#     <div class="flex flex-wrap justify-end lg:justify-between items-center">
#      <div class="w-full lg:w-auto cars-price text-right pt-1">
#       €15900
#      </div>
#      <div class="inline-flex items-center">
#       <span class="cars-bolder-txt pt-1">
#        € 246
#       </span>
#       <div class="price-block-green ml-2">
#        <span>
#         €
#        </span>
#        <span class="text-xs">
#         mēn.
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="cars__bottom">
#     <div class="border-b">
#      <div class="inline-flex items-end">
#       <a class="button-more" href="https://lv.brcauto.eu/automobilis/c863142-porsche-boxster-2.7l-automatiska">
#        <svg class="fill-current" height="12" width="7">
#         <use xlink:href="#arrow-r">
#         </use>
#        </svg>
#       </a>
#       <span class="pl-4 mb-2">
#       </span>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
#  <div class="cars-wrapper">
#   <div class="cars">
#    <div class="cars__top">
#     <h2 class="cars__title">
#      <a href="https://lv.brcauto.eu/automobilis/c862956-porsche-911-3.4l-automatiska">
#       Porsche 911 Carrera 2 AT Aero Kit
#      </a>
#     </h2>
#     <p class="cars__subtitle">
#      1999 | 3.4 Benzīns | Automātiskā | 118670 km | 221 kW (301 HP) | Zila
#     </p>
#    </div>
#    <div class="cars__img">
#     <a href="https://lv.brcauto.eu/automobilis/c862956-porsche-911-3.4l-automatiska">
#      <img alt="Porsche 911 Carrera 2 AT Aero Kit " class="lazy cars__img-primary" data-src="https://media.brcauto.eu/cars/list_grid/862956_1.jpg" src="#"/>
#     </a>
#    </div>
#    <div class="cars__middle">
#     <div class="flex flex-wrap justify-end lg:justify-between items-center">
#      <div class="w-full lg:w-auto cars-price text-right pt-1">
#       €25900
#      </div>
#      <div class="inline-flex items-center">
#       <span class="cars-bolder-txt pt-1">
#        € 400
#       </span>
#       <div class="price-block-green ml-2">
#        <span>
#         €
#        </span>
#        <span class="text-xs">
#         mēn.
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="cars__bottom">
#     <div class="border-b">
#      <div class="inline-flex items-end">
#       <a class="button-more" href="https://lv.brcauto.eu/automobilis/c862956-porsche-911-3.4l-automatiska">
#        <svg class="fill-current" height="12" width="7">
#         <use xlink:href="#arrow-r">
#         </use>
#        </svg>
#       </a>
#       <span class="pl-4 mb-2">
#       </span>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
#  <div class="cars-wrapper">
#   <div class="cars">
#    <div class="cars__top">
#     <h2 class="cars__title">
#      <a href="https://lv.brcauto.eu/automobilis/c860585-porsche-cayenne-3.6l-automatiska">
#       Porsche Cayenne A/T
#      </a>
#     </h2>
#     <p class="cars__subtitle">
#      2010 | 3.6 Benzīns | Automātiskā | 172024 km | 220 kW (299 HP) | Melna
#     </p>
#    </div>
#    <div class="cars__img">
#     <a href="https://lv.brcauto.eu/automobilis/c860585-porsche-cayenne-3.6l-automatiska">
#      <img alt="Porsche Cayenne A/T" class="lazy cars__img-primary" data-src="https://media.brcauto.eu/cars/list_grid/860585_1.jpg" src="#"/>
#     </a>
#    </div>
#    <div class="cars__middle">
#     <div class="flex flex-wrap justify-end lg:justify-between items-center">
#      <div class="w-full lg:w-auto cars-price text-right pt-1">
#       €17900
#      </div>
#      <div class="inline-flex items-center">
#       <span class="cars-bolder-txt pt-1">
#        € 277
#       </span>
#       <div class="price-block-green ml-2">
#        <span>
#         €
#        </span>
#        <span class="text-xs">
#         mēn.
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="cars__bottom">
#     <div class="border-b">
#      <div class="inline-flex items-end">
#       <a class="button-more" href="https://lv.brcauto.eu/automobilis/c860585-porsche-cayenne-3.6l-automatiska">
#        <svg class="fill-current" height="12" width="7">
#         <use xlink:href="#arrow-r">
#         </use>
#        </svg>
#       </a>
#       <span class="pl-4 mb-2">
#        <span class="block">
#         PVN iekļauts
#        </span>
#       </span>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
#  <div class="cars-wrapper">
#   <div class="cars">
#    <div class="cars__top">
#     <h2 class="cars__title">
#      <a href="https://lv.brcauto.eu/automobilis/c856921-porsche-macan-2.0l-automatiska">
#       Porsche Macan 2.0T PDK
#      </a>
#     </h2>
#     <p class="cars__subtitle">
#      2018 | 2.0 Benzīns | Automātiskā | 95428 km | 185 kW (252 HP) | Brūna
#     </p>
#    </div>
#    <div class="cars__img">
#     <a href="https://lv.brcauto.eu/automobilis/c856921-porsche-macan-2.0l-automatiska">
#      <img alt="Porsche Macan 2.0T PDK" class="lazy cars__img-primary" data-src="https://media.brcauto.eu/cars/list_grid/856921_1.jpg" src="#"/>
#     </a>
#    </div>
#    <div class="cars__middle">
#     <div class="flex flex-wrap justify-end lg:justify-between items-center">
#      <div class="w-full lg:w-auto cars-price text-right pt-1">
#       €35900
#      </div>
#      <div class="inline-flex items-center">
#       <span class="cars-bolder-txt pt-1">
#        € 555
#       </span>
#       <div class="price-block-green ml-2">
#        <span>
#         €
#        </span>
#        <span class="text-xs">
#         mēn.
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="cars__bottom">
#     <div class="border-b">
#      <div class="inline-flex items-end">
#       <a class="button-more" href="https://lv.brcauto.eu/automobilis/c856921-porsche-macan-2.0l-automatiska">
#        <svg class="fill-current" height="12" width="7">
#         <use xlink:href="#arrow-r">
#         </use>
#        </svg>
#       </a>
#       <span class="pl-4 mb-2">
#        <span class="block">
#         PVN iekļauts
#        </span>
#       </span>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
#  <div class="cars-wrapper">
#   <div class="cars">
#    <div class="cars__top">
#     <h2 class="cars__title">
#      <a href="https://lv.brcauto.eu/automobilis/c861119-porsche-997-3.8l-automatiska">
#       Porsche 997 Carrera 2 GTS
#      </a>
#     </h2>
#     <p class="cars__subtitle">
#      2011 | 3.8 Benzīns | Automātiskā | 23182 mil | 300 kW (408 HP) | Zila
#     </p>
#    </div>
#    <div class="cars__img">
#     <a href="https://lv.brcauto.eu/automobilis/c861119-porsche-997-3.8l-automatiska">
#      <img alt="Porsche 997 Carrera 2 GTS" class="lazy cars__img-primary" data-src="https://media.brcauto.eu/cars/list_grid/861119_1.jpg" src="#"/>
#     </a>
#    </div>
#    <div class="cars__middle">
#     <div class="flex flex-wrap justify-end lg:justify-between items-center">
#      <div class="w-full lg:w-auto cars-price text-right pt-1">
#       €89900
#      </div>
#      <div class="inline-flex items-center">
#       <span class="cars-bolder-txt pt-1">
#        € 1390
#       </span>
#       <div class="price-block-green ml-2">
#        <span>
#         €
#        </span>
#        <span class="text-xs">
#         mēn.
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="cars__bottom">
#     <div class="border-b">
#      <div class="inline-flex items-end">
#       <a class="button-more" href="https://lv.brcauto.eu/automobilis/c861119-porsche-997-3.8l-automatiska">
#        <svg class="fill-current" height="12" width="7">
#         <use xlink:href="#arrow-r">
#         </use>
#        </svg>
#       </a>
#       <span class="pl-4 mb-2">
#        <span class="block">
#         PVN iekļauts
#        </span>
#       </span>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
#  <div class="cars-wrapper">
#   <div class="cars">
#    <div class="cars__top">
#     <h2 class="cars__title">
#      <a href="https://lv.brcauto.eu/automobilis/c840574-porsche-cayenne-4.8l-automatiska">
#       Porsche Cayenne Turbo Techart Magnum
#      </a>
#     </h2>
#     <p class="cars__subtitle">
#      2011 | 4.8 Benzīns | Automātiskā | 112900 km | 368 kW (500 HP) | Balta
#     </p>
#    </div>
#    <div class="cars__img">
#     <a href="https://lv.brcauto.eu/automobilis/c840574-porsche-cayenne-4.8l-automatiska">
#      <img alt="Porsche Cayenne Turbo Techart Magnum " class="lazy cars__img-primary" data-src="https://media.brcauto.eu/cars/list_grid/840574_1.jpg" src="#"/>
#     </a>
#    </div>
#    <div class="cars__middle">
#     <div class="flex flex-wrap justify-end lg:justify-between items-center">
#      <div class="w-full lg:w-auto cars-price text-right pt-1">
#       €36500
#      </div>
#      <div class="inline-flex items-center">
#       <span class="cars-bolder-txt pt-1">
#        € 564
#       </span>
#       <div class="price-block-green ml-2">
#        <span>
#         €
#        </span>
#        <span class="text-xs">
#         mēn.
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="cars__bottom">
#     <div class="border-b">
#      <div class="inline-flex items-end">
#       <a class="button-more" href="https://lv.brcauto.eu/automobilis/c840574-porsche-cayenne-4.8l-automatiska">
#        <svg class="fill-current" height="12" width="7">
#         <use xlink:href="#arrow-r">
#         </use>
#        </svg>
#       </a>
#       <span class="pl-4">
#        <span class="block cars-status">
#         SAZINĀTIES
#        </span>
#       </span>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
#  <div class="cars-wrapper">
#   <div class="cars">
#    <div class="cars__top">
#     <h2 class="cars__title">
#      <a href="https://lv.brcauto.eu/automobilis/c857395-porsche-panamera-3.0l-automatiska">
#       Porsche Panamera 4
#      </a>
#     </h2>
#     <p class="cars__subtitle">
#      2018 | 3.0 Benzīns | Automātiskā | 66890 km | 243 kW (330 HP) | Balta
#     </p>
#    </div>
#    <div class="cars__img">
#     <a href="https://lv.brcauto.eu/automobilis/c857395-porsche-panamera-3.0l-automatiska">
#      <img alt="Porsche Panamera 4" class="lazy cars__img-primary" data-src="https://media.brcauto.eu/cars/list_grid/857395_1.jpg" src="#"/>
#     </a>
#    </div>
#    <div class="cars__middle">
#     <div class="flex flex-wrap justify-end lg:justify-between items-center">
#      <div class="w-full lg:w-auto cars-price text-right pt-1">
#       €59900
#      </div>
#      <div class="inline-flex items-center">
#       <span class="cars-bolder-txt pt-1">
#        € 926
#       </span>
#       <div class="price-block-green ml-2">
#        <span>
#         €
#        </span>
#        <span class="text-xs">
#         mēn.
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="cars__bottom">
#     <div class="border-b">
#      <div class="inline-flex items-end">
#       <a class="button-more" href="https://lv.brcauto.eu/automobilis/c857395-porsche-panamera-3.0l-automatiska">
#        <svg class="fill-current" height="12" width="7">
#         <use xlink:href="#arrow-r">
#         </use>
#        </svg>
#       </a>
#       <span class="pl-4 mb-2">
#       </span>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
#  <div class="cars-wrapper">
#   <div class="cars">
#    <div class="cars__top">
#     <h2 class="cars__title">
#      <a href="https://lv.brcauto.eu/automobilis/c843520-porsche-cayenne-4.8l-automatiska">
#       Porsche Cayenne S
#      </a>
#     </h2>
#     <p class="cars__subtitle">
#      2012 | 4.8 Benzīns | Automātiskā | 234617 km | 294 kW (400 HP) | Balta
#     </p>
#    </div>
#    <div class="cars__img">
#     <a href="https://lv.brcauto.eu/automobilis/c843520-porsche-cayenne-4.8l-automatiska">
#      <img alt="Porsche Cayenne S" class="lazy cars__img-primary" data-src="https://media.brcauto.eu/cars/list_grid/843520_1.jpg" src="#"/>
#     </a>
#    </div>
#    <div class="cars__middle">
#     <div class="flex flex-wrap justify-end lg:justify-between items-center">
#      <div class="w-full lg:w-auto cars-price text-right pt-1">
#       €14900
#      </div>
#      <div class="inline-flex items-center">
#       <span class="cars-bolder-txt pt-1">
#        € 230
#       </span>
#       <div class="price-block-green ml-2">
#        <span>
#         €
#        </span>
#        <span class="text-xs">
#         mēn.
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="cars__bottom">
#     <div class="border-b">
#      <div class="inline-flex items-end">
#       <a class="button-more" href="https://lv.brcauto.eu/automobilis/c843520-porsche-cayenne-4.8l-automatiska">
#        <svg class="fill-current" height="12" width="7">
#         <use xlink:href="#arrow-r">
#         </use>
#        </svg>
#       </a>
#       <span class="pl-4 mb-2">
#       </span>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
# </div>

# %%
def parse_price(price_str):
    return float(price_str.replace('€', '').replace(',', ''))

def sort_cars_by_price(cars):
    return sorted(cars, key=lambda x: parse_price(x[2].getText().strip()))

def fetch_and_print_subtitles(div, title_tag, title_class, spec_tag, spec_class, price_tag, price_class):
    titles = fetch_subtitles(div, title_tag, title_class)
    specs = fetch_subtitles(div, spec_tag, spec_class)
    prices = fetch_subtitles(div, price_tag, price_class)
    
    if titles and specs and prices:
        cars = list(zip(titles, specs, prices))
        sorted_cars = sort_cars_by_price(cars)
        
        for i, (title, spec, price) in enumerate(sorted_cars, 1):
            print(f"Car {i}:")
            print(f"{title.getText().strip()} - {spec.getText().strip()}")
            print(f"Price: {price.getText().strip()}")
            print("-" * 100)
    elif not titles:
        print(f"No titles with class '{title_class}' found inside the div")
    elif not specs:
        print(f"No specs with class '{spec_class}' found inside the div")
    elif not prices:
        print(f"No prices with class '{price_class}' found inside the div")
    else:
        print("No matching titles, specs, and prices found")

# Usage
fetch_and_print_subtitles(div, 'h2', "cars__title", 'p', "cars__subtitle", 'div', 'w-full lg:w-auto cars-price text-right pt-1')
# Out:
# Car 1:
# Porsche Cayenne M/T - 2007 | 3.6 Benzīns | Mehāniskā | 92070 km | 213 kW (290 HP) | Melna
# Price: €13900
# ----------------------------------------------------------------------------------------------------
# Car 2:
# Porsche Cayenne S - 2012 | 4.8 Benzīns | Automātiskā | 234617 km | 294 kW (400 HP) | Balta
# Price: €14900
# ----------------------------------------------------------------------------------------------------
# Car 3:
# Porsche Boxster M/T - 2002 | 2.7 Benzīns | Automātiskā | 38294 km | 162 kW (220 HP) | Sarkana
# Price: €15900
# ----------------------------------------------------------------------------------------------------
# Car 4:
# Porsche Boxster M/T - 2003 | 2.7 Benzīns | Mehāniskā | 93311 km | 168 kW (228 HP) | Sudraba
# Price: €16900
# ----------------------------------------------------------------------------------------------------
# Car 5:
# Porsche Cayenne A/T - 2010 | 3.6 Benzīns | Automātiskā | 172024 km | 220 kW (299 HP) | Melna
# Price: €17900
# ----------------------------------------------------------------------------------------------------
# Car 6:
# Porsche 968 Coupe Manual M030 - 1993 | 3.0 Benzīns | Mehāniskā | 114652 mil | 176 kW (239 HP) | Balta
# Price: €22500
# ----------------------------------------------------------------------------------------------------
# Car 7:
# Porsche 911 Carrera 2 AT Aero Kit - 1999 | 3.4 Benzīns | Automātiskā | 118670 km | 221 kW (301 HP) | Zila
# Price: €25900
# ----------------------------------------------------------------------------------------------------
# Car 8:
# Porsche Macan 2.0T PDK - 2018 | 2.0 Benzīns | Automātiskā | 95428 km | 185 kW (252 HP) | Brūna
# Price: €35900
# ----------------------------------------------------------------------------------------------------
# Car 9:
# Porsche Cayenne Turbo Techart Magnum - 2011 | 4.8 Benzīns | Automātiskā | 112900 km | 368 kW (500 HP) | Balta
# Price: €36500
# ----------------------------------------------------------------------------------------------------
# Car 10:
# Porsche Cayenne 3.0T AT - 2018 | 3.0 Benzīns | Automātiskā | 85410 km | 250 kW (340 HP) | Melna
# Price: €46500
# ----------------------------------------------------------------------------------------------------
# Car 11:
# Porsche 997 Targa 4S M/T - 2006 | 3.8 Benzīns | Mehāniskā | 46714 km | 261 kW (355 HP) | Sarkana
# Price: €57000
# ----------------------------------------------------------------------------------------------------
# Car 12:
# Porsche Panamera 4 - 2018 | 3.0 Benzīns | Automātiskā | 66890 km | 243 kW (330 HP) | Balta
# Price: €59900
# ----------------------------------------------------------------------------------------------------
# Car 13:
# Porsche Taycan Performance Performance Plus - Elektro | Automātiskā | 280 kW (381 AG) | 65588 km
# Price: €62000
# ----------------------------------------------------------------------------------------------------
# Car 14:
# Porsche 997 Carrera 2 GTS - 2011 | 3.8 Benzīns | Automātiskā | 23182 mil | 300 kW (408 HP) | Zila
# Price: €89900
# ----------------------------------------------------------------------------------------------------
# Car 15:
# Porsche 911 GT3 Clubsport - 2018 | 4.0 Benzīns | Automātiskā | 19627 km | 368 kW (500 HP) | Melna
# Price: €149900
# ----------------------------------------------------------------------------------------------------
